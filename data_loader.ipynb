# %% [markdown]
# # List of necessary pip packages which will make the data analysis streamlined

# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/e5/63/cd7d615331b328e287d8233ba9fdf191a9c2d11b6af0c7a59cfcec23de68/pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.1 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/f9/58/30a85127bfee6f108282107caf8e06a1f0cc997cb6b52cdee699276fcce4/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 16.8 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
# ...

# %% [markdown]
# # Reading the MI Manager Task CSV into my notebook for analysis

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path() / '/workspaces/snr_data_analyst_lendable/MI Manager Test - Raw Data - MI Manager Test - Raw Data.csv')
df.head()
# Out:
#                 ID            CREATED_AT SOURCE_DELIVERED_AS  \
# 0  215469298667024  2025-06-05T01:22:10Z  customer_initiated
# 1  215469420694920  2025-06-13T13:42:25Z  customer_initiated
# 2  215469391633724  2025-06-11T15:18:41Z  customer_initiated
# 3  215469368062515  2025-06-10T09:45:30Z     admin_initiated
# 4  215469352476396  2025-06-09T11:05:55Z  customer_initiated
#
#   FIRST_CONTACT_REPLY_CREATED_AT CONVERSATION_RATING_CREATED_AT  \
# 0           2025-06-05T01:22:10Z                            NaN
# 1           2025-06-13T13:42:25Z                            NaN
# 2           2025-06-11T15:18:41Z                            NaN
# 3           2025-06-10T11:08:31Z                            NaN
# 4           2025-06-09T11:05:55Z                            NaN
#
#    CONVERSATION_RATING_VALUE  CONVERSATION_RATING_TEAMMATE_ID  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# ...

# %% [markdown]
# # Initial assumptions
# 1. We need to view the data types of all columns and ensure there is standardisation in the dataset. This will help providing a source of truth for downstream models or dashboards in this example.
# 2. What will the data be used for, before rushing to do data analysis I must understand the use cases for the data and gather specific requirements so I am working towards my stakeholders ideal output
